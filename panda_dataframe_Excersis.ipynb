# %%
import pandas as pd
from datetime import datetime
import matplotlib as plt
# %matplotlib inline

# %%
# Create an empty pandas DataFrame
pd.DataFrame(data=[None],index=[None],columns=[None])
# Create a marvel_df pandas DataFrame with the given marvel data
# Add column names to the marvel_df
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]
data = pd.DataFrame(marvel_data,columns=['name', 'sex', 'first_appearance'])
# Drop the name column as it's now the index 
# Drop the name column as it's now the index
data.set_index("name",inplace=True)
# Drop 'Namor' and 'Hank Pym' rows
print(data.drop(['Namor','Hank Pym'],axis=0).shape)
# Out:
# (18, 2)
# name
# Spider-Man          1962
# Captain America     1941
# Wolverine           1974
# Iron Man            1963
# Thor                1963
# Thing               1961
# Mister Fantastic    1961
# Hulk                1962
# Beast               1963
# Invisible Woman     1961
# Storm               1975
# Namor               1939
# Hawkeye             1964
# Daredevil           1964
# Doctor Strange      1963
# Hank Pym            1962
# Scarlet Witch       1964
# Wasp                1963
# Black Widow         1964
# Vision              1968
# Name: first_appearance, dtype: int64

# %%
# Show the first 5 elements on marvel_df
data.head(5)
# Show the last 5 elements on marvel_df
data.tail(5)
# Show just the sex of the first 5 elements on marvel_df
data["sex"].iloc[:5].values
# Out:
# array(['male', 'male', 'male', 'male', 'male'], dtype=object)

# %%
# Show the first_appearance of all middle elements on marvel_df
data.iloc[1:-1]["first_appearance"]
# Out:
# name
# Captain America     1941
# Wolverine           1974
# Iron Man            1963
# Thor                1963
# Thing               1961
# Mister Fantastic    1961
# Hulk                1962
# Beast               1963
# Invisible Woman     1961
# Storm               1975
# Namor               1939
# Hawkeye             1964
# Daredevil           1964
# Doctor Strange      1963
# Hank Pym            1962
# Scarlet Witch       1964
# Wasp                1963
# Black Widow         1964
# Name: first_appearance, dtype: int64

# %%
# Show the first and last elements on marvel_df
data.iloc[[0,-1]]
# Out:
#              sex  first_appearance
# name
# Spider-Man  male              1962
# Vision      male              1968

# %%
# Modify the first_appearance of 'Vision' to year 1964
data.loc['Vision','first_appearance'] = 1964
data
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1964

# %%
# Add a new column to marvel_df called 'years_since' with the years since first_appearance
data['first_appearance'] = pd.to_datetime(data['first_appearance']).dt.year
data['years_since']= datetime.now().year - data['first_appearance']
data
# Out:
#                      sex  first_appearance  years_since
# name
# Spider-Man          male              1970           54
# Captain America     male              1970           54
# Wolverine           male              1970           54
# Iron Man            male              1970           54
# Thor                male              1970           54
# Thing               male              1970           54
# Mister Fantastic    male              1970           54
# Hulk                male              1970           54
# Beast               male              1970           54
# Invisible Woman   female              1970           54
# Storm             female              1970           54
# Namor               male              1970           54
# Hawkeye             male              1970           54
# Daredevil           male              1970           54
# Doctor Strange      male              1970           54
# Hank Pym            male              1970           54
# ...

# %%
# Given the marvel_df pandas DataFrame, make a mask showing the female characters
data["sex"]=="female"
# Out:
# name
# Spider-Man          False
# Captain America     False
# Wolverine           False
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman      True
# Storm                True
# Namor               False
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Hank Pym            False
# Scarlet Witch        True
# Wasp                 True
# Black Widow          True
# Vision              False
# Name: sex, dtype: bool

# %%
# Given the marvel_df pandas DataFrame, get the male characters
data[(data["sex"]=="female")==False].index
# Out:
# Index(['Spider-Man', 'Captain America', 'Wolverine', 'Iron Man', 'Thor',
#        'Thing', 'Mister Fantastic', 'Hulk', 'Beast', 'Namor', 'Hawkeye',
#        'Daredevil', 'Doctor Strange', 'Hank Pym', 'Vision'],
#       dtype='object', name='name')

# %%
# Given the marvel_df pandas DataFrame, get the characters with first_appearance after 1970
data[data['first_appearance']>1970]
# Out:
#               sex  first_appearance
# name
# Wolverine    male              1974
# Storm      female              1975

# %%
# Given the marvel_df pandas DataFrame, get the female characters with first_appearance after 1970
data[(data['first_appearance']>1970)&(data["sex"]=="female")]
# Out:
#           sex  first_appearance
# name
# Storm  female              1975

# %%
# Show basic statistics of marvel_df
print(data.describe())
# Given the marvel_df pandas DataFrame, show the mean value of first_appearance
print(data["first_appearance"].mean())
# Given the marvel_df pandas DataFrame, show the min value of first_appearance
print(data["first_appearance"].min())
# Out:
#        first_appearance
# count         20.000000
# mean        1961.850000
# std            8.405982
# min         1939.000000
# 25%         1961.750000
# 50%         1963.000000
# 75%         1964.000000
# max         1975.000000
# 1961.85
# 1939

# %%
# Given the marvel_df pandas DataFrame, get the characters with the min value of first_appearance
data[(data["first_appearance"]==data["first_appearance"].min())].index
# Out:
# Index(['Namor'], dtype='object', name='name')

# %%
# Reset index names of marvel_df
data.reset_index()
# Out:
#                 name     sex  first_appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %%
#Plot a histogram (plot.hist) with values of first_appearance
data["first_appearance"].plot(kind="hist")
plt.pyplot.show()
